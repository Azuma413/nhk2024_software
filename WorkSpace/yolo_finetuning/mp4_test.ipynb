# %%
import cv2
from ultralytics import YOLO
import torch
print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# torch 2.2.1+cu121 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3090', major=8, minor=6, total_memory=24575MB, multi_processor_count=82)

# %%
model = YOLO('./runs/detect/train8/weights/best.pt')
video_path = './blue_video/IMG_8134.MOV'
cap = cv2.VideoCapture(video_path)
annotated_frames = []
while cap.isOpened(): # フレームがある間繰り返す
    ret, frame = cap.read()
    if ret:
        results = model.track(frame, persist=True)
        annotated_frame = results[0].plot()
    else:
        break
    annotated_frames.append(annotated_frame)
# annotated_framesをmp4として保存
height, width, layers = annotated_frames[0].shape
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video = cv2.VideoWriter('./purple_video/train8_video0.mp4', fourcc, 30, (width, height))
# ./video/annotated_video.mp4として保存
for frame in annotated_frames:
    video.write(frame)
video.release()
cap.release()
cv2.destroyAllWindows()
print('finished')
# Out:
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#    ---------------------------------------- 1.5/1.5 MB 7.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 2.8/2.8 MB 16.1 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success  3.8s, installed 1 package: ['lapx>=0.5.2']
# requirements:  Restart runtime or rerun command for updates to take effect
#
#
# 0: 384x640 4 blues, 5 reds, 87.5ms
# Speed: 3.0ms preprocess, 87.5ms inference, 877.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 blues, 5 reds, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 blues, 5 reds, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 blues, 5 reds, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 blues, 6 reds, 16.3ms
# ...
